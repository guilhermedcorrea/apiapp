# %%
import requests
import json

# %%
payload = json.dumps({
  "id": "string",
  "payment": [
    {
      "paymentDetail": [
        {
          "method": "cash",
          "amount": 0,
          "card": {
            "federalTaxNumber": "string",
            "flag": "visa",
            "authorization": "string",
            "integrationPaymentType": "integrated"
          }
        }
      ],
      "payBack": 0
    }
  ],
  "serie": 0,
  "number": 0,
  "operationOn": "2022-10-17T05:38:51.708Z",
  "operationNature": "string",
  "operationType": "incoming",
  "destination": "international_Operation",
  "printType": "none",
  "purposeType": "devolution",
  "consumerType": "normal",
  "presenceType": "none",
  "contingencyOn": "2022-10-17T05:38:51.708Z",
  "contingencyJustification": "string",
  "buyer": {
    "stateTaxNumberIndicator": "none",
    "tradeName": "string",
    "taxRegime": "none",
    "stateTaxNumber": "string",
    "id": "string",
    "name": "string",
    "federalTaxNumber": 0,
    "email": "string",
    "address": {
      "phone": "string",
      "state": "string",
      "city": {
        "code": "string",
        "name": "string"
      },
      "district": "string",
      "additionalInformation": "string",
      "street": "string",
      "number": "string",
      "postalCode": "string",
      "country": "string"
    },
    "type": "undefined"
  },
  "totals": {
    "icms": {
      "baseTax": 0,
      "icmsAmount": 0,
      "icmsExemptAmount": 0,
      "stCalculationBasisAmount": 0,
      "stAmount": 0,
      "productAmount": 0,
      "freightAmount": 0,
      "insuranceAmount": 0,
      "discountAmount": 0,
      "iiAmount": 0,
      "ipiAmount": 0,
      "pisAmount": 0,
      "cofinsAmount": 0,
      "othersAmount": 0,
      "invoiceAmount": 0,
      "fcpufDestinationAmount": 0,
      "icmsufDestinationAmount": 0,
      "icmsufSenderAmount": 0,
      "federalTaxesAmount": 0,
      "fcpAmount": 0,
      "fcpstAmount": 0,
      "fcpstRetAmount": 0,
      "ipiDevolAmount": 0
    },
    "issqn": {
      "totalServiceNotTaxedICMS": 0,
      "baseRateISS": 0,
      "totalISS": 0,
      "valueServicePIS": 0,
      "valueServiceCOFINS": 0,
      "provisionService": "2022-10-17T05:38:51.708Z",
      "deductionReductionBC": 0,
      "valueOtherRetention": 0,
      "discountUnconditional": 0,
      "discountConditioning": 0,
      "totalRetentionISS": 0,
      "codeTaxRegime": 0
    }
  },
  "transport": {
    "freightModality": "byIssuer",
    "transportGroup": {
      "stateTaxNumber": "string",
      "transportRetention": "string",
      "id": "string",
      "name": "string",
      "federalTaxNumber": 0,
      "email": "string",
      "address": {
        "phone": "string",
        "state": "string",
        "city": {
          "code": "string",
          "name": "string"
        },
        "district": "string",
        "additionalInformation": "string",
        "street": "string",
        "number": "string",
        "postalCode": "string",
        "country": "string"
      },
      "type": "undefined"
    },
    "reboque": {
      "plate": "string",
      "uf": "string",
      "rntc": "string",
      "wagon": "string",
      "ferry": "string"
    },
    "volume": {
      "volumeQuantity": 0,
      "species": "string",
      "brand": "string",
      "volumeNumeration": "string",
      "netWeight": 0,
      "grossWeight": 0
    },
    "transportVehicle": {
      "plate": "string",
      "state": "string",
      "rntc": "string"
    },
    "sealNumber": "string",
    "transpRate": {
      "serviceAmount": 0,
      "bcRetentionAmount": 0,
      "icmsRetentionRate": 0,
      "icmsRetentionAmount": 0,
      "cfop": 0,
      "cityGeneratorFactCode": 0
    }
  },
  "additionalInformation": {
    "fisco": "string",
    "taxpayer": "string",
    "xmlAuthorized": [
      0
    ],
    "effort": "string",
    "order": "string",
    "contract": "string",
    "taxDocumentsReference": [
      {
        "taxCouponInformation": {
          "modelDocumentFiscal": "string",
          "orderECF": "string",
          "orderCountOperation": 0
        },
        "documentInvoiceReference": {
          "state": 0,
          "yearMonth": "string",
          "federalTaxNumber": "string",
          "model": "string",
          "series": "string",
          "number": "string"
        },
        "documentElectronicInvoice": {
          "accessKey": "string"
        }
      }
    ],
    "taxpayerComments": [
      {
        "field": "string",
        "text": "string"
      }
    ],
    "referencedProcess": [
      {
        "identifierConcessory": "string",
        "identifierOrigin": 0
      }
    ]
  },
  "items": [
    {
      "code": "string",
      "codeGTIN": "string",
      "description": "string",
      "ncm": "string",
      "cfop": 0,
      "unit": "string",
      "quantity": 0,
      "unitAmount": 0,
      "totalAmount": 0,
      "unitTax": "string",
      "quantityTax": 0,
      "taxUnitAmount": 0,
      "freightAmount": 0,
      "insuranceAmount": 0,
      "discountAmount": 0,
      "othersAmount": 0,
      "totalIndicator": True,
      "cest": "string",
      "tax": {
        "totalTax": 0,
        "icms": {
          "origin": "string",
          "cst": "string",
          "baseTaxModality": "string",
          "baseTax": 0,
          "baseTaxSTModality": "string",
          "baseTaxSTReduction": "string",
          "baseTaxST": 0,
          "baseTaxReduction": 0,
          "stRate": 0,
          "stAmount": 0,
          "stMarginAmount": 0,
          "csosn": "string",
          "rate": 0,
          "amount": 0,
          "percentual": 0,
          "snCreditRate": 0,
          "snCreditAmount": 0,
          "stMarginAddedAmount": "string",
          "stRetentionAmount": "string",
          "baseSTRetentionAmount": "string",
          "baseTaxOperationPercentual": "string",
          "ufst": "string",
          "amountSTReason": "string",
          "baseSNRetentionAmount": "string",
          "snRetentionAmount": "string",
          "amountOperation": "string",
          "percentualDeferment": "string",
          "baseDeferred": "string",
          "exemptAmount": 0,
          "exemptReason": "agriculture",
          "fcpRate": 0,
          "fcpAmount": 0,
          "fcpstRate": 0,
          "fcpstAmount": 0,
          "fcpstRetRate": 0,
          "fcpstRetAmount": 0,
          "baseTaxFCPSTAmount": 0,
          "substituteAmount": 0
        },
        "ipi": {
          "classification": "string",
          "producerCNPJ": "string",
          "stampCode": "string",
          "stampQuantity": 0,
          "classificationCode": "string",
          "cst": "string",
          "base": 0,
          "rate": 0,
          "unitQuantity": 0,
          "unitAmount": 0,
          "amount": 0
        },
        "ii": {
          "baseTax": "string",
          "customsExpenditureAmount": "string",
          "amount": 0,
          "iofAmount": 0
        },
        "pis": {
          "cst": "string",
          "baseTax": 0,
          "rate": 0,
          "amount": 0,
          "baseTaxProductQuantity": 0,
          "productRate": 0
        },
        "cofins": {
          "cst": "string",
          "baseTax": 0,
          "rate": 0,
          "amount": 0,
          "baseTaxProductQuantity": 0,
          "productRate": 0
        },
        "icmsDestination": {
          "vBCUFDest": 0,
          "pFCPUFDest": 0,
          "pICMSUFDest": 0,
          "pICMSInter": 0,
          "pICMSInterPart": 0,
          "vFCPUFDest": 0,
          "vICMSUFDest": 0,
          "vICMSUFRemet": 0,
          "vBCFCPUFDest": 0
        }
      },
      "additionalInformation": "string",
      "numberOrderBuy": "string",
      "itemNumberOrderBuy": 0,
      "fuelDetail": {
        "codeANP": "string",
        "percentageNG": 0,
        "descriptionANP": "string",
        "percentageGLP": 0,
        "percentageNGn": 0,
        "percentageGNi": 0,
        "startingAmount": 0,
        "codif": "string",
        "amountTemp": 0,
        "stateBuyer": "string",
        "cide": {
          "bc": 0,
          "rate": 0,
          "cideAmount": 0
        },
        "pump": {
          "spoutNumber": 0,
          "number": 0,
          "tankNumber": 0,
          "beginningAmount": 0,
          "endAmount": 0
        }
      },
      "benefit": "string",
      "importDeclarations": [
        {
          "code": "string",
          "registeredOn": "2022-10-17T05:38:51.709Z",
          "customsClearanceName": "string",
          "customsClearanceState": "rO",
          "customsClearancedOn": "2022-10-17T05:38:51.709Z",
          "additions": [
            {
              "code": 0,
              "manufacturer": "string",
              "amount": 0,
              "drawback": 0
            }
          ],
          "exporter": "string",
          "internationalTransport": "none",
          "intermediation": "none"
        }
      ]
    }
  ],
  "billing": {
    "bill": {
      "number": "string",
      "originalAmount": 0,
      "discountAmount": 0,
      "netAmount": 0
    },
    "duplicates": [
      {
        "number": "string",
        "expirationOn": "2022-10-17T05:38:51.709Z",
        "amount": 0
      }
    ]
  },
  "issuer": {
    "stStateTaxNumber": "string"
  },
  "transactionIntermediate": {
    "federalTaxNumber": 0,
    "identifier": "string"
  },
  "delivery": {
    "stateTaxNumber": "string",
    "id": "string",
    "name": "string",
    "federalTaxNumber": 0,
    "email": "string",
    "address": {
      "phone": "string",
      "state": "string",
      "city": {
        "code": "string",
        "name": "string"
      },
      "district": "string",
      "additionalInformation": "string",
      "street": "string",
      "number": "string",
      "postalCode": "string",
      "country": "string"
    },
    "type": "undefined"
  },
  "withdrawal": {
    "stateTaxNumber": "string",
    "id": "string",
    "name": "string",
    "federalTaxNumber": 0,
    "email": "string",
    "address": {
      "phone": "string",
      "state": "string",
      "city": {
        "code": "string",
        "name": "string"
      },
      "district": "string",
      "additionalInformation": "string",
      "street": "string",
      "number": "string",
      "postalCode": "string",
      "country": "string"
    },
    "type": "undefined"
  }
})

# %%
#cadastro nf
def teste():
    url = """https://api.nfse.io/v2/companies/acd0c1c8f5a1486592c6ed80d94e2bb7/productinvoices?apikey=t0StUhoH4JiSN72ehwrhq3nQ27gRDTSJGt2W98rDXilRTwhNoJAiGtM9WUcl9MscjjW"""
    headers = {
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)

    print(response.status_code)
    print(response.json())


a = teste()
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 14
#      10     print(response.status_code)
#      11     print(response.json())
# ---> 14 a = teste()
#      15 print(a)
#
# Cell In [3], line 8, in teste()
#       3 url = """https://api.nfse.io/v2/companies/acd0c1c8f5a1486592c6ed80d94e2bb7/productinvoices?apikey=t0StUhoH4JiSN72ehwrhq3nQ27gRDTSJGt2W98rDXilRTwhNoJAiGtM9WUcl9MscjjW"""
#       4 headers = {
#       5 'Content-Type': 'application/json'
#       6 }
# ----> 8 response = requests.request("POST", url, headers=headers, data=payload)
#      10 print(response.status_code)
#      11 print(response.json())
#
# NameError: name 'payload' is not defined

# %%
#https://nfe.io/docs/desenvolvedores/rest-api/nota-fiscal-de-consumidor-v2/#/Consumer%20Invoices/V2CompaniesByCompany_idConsumerinvoicesGet

# %%
def lista_nf():
    #companies/consumerinvoices
    #listas as nf

    url = "https://api.nfse.io/v2/companies/acd0c1c8f5a1486592c6ed80d94e2bb7/consumerinvoices?q=EMPRESA%20LTDA&apikey=4u6xx4hL3T8EyzSs8FvpmJTBQbJHTlodtVdHE8OSN5iPq3dTepZiw5v31PsQK8rmb2a


    payload = ""
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    print(response.text)

# %%
#companies/consumerinvoices
#consulta_por_id
def lista_nf_consumidor():
    import requests

url = "https://api.nfse.io/v2/companies/acd0c1c8f5a1486592c6ed80d94e2bb7/consumerinvoices/0?apikey=4u6xx4hL3T8EyzSs8FvpmJTBQbJHTlodtVdHE8OSN5iPq3dTepZiw5v31PsQK8rmb2a
"

    payload = ""
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    print(response.text)

# %%
import requests
import json

url = "https://api.nfse.io/v2/companies/acd0c1c8f5a1486592c6ed80d94e2bb7/productinvoices/"

payload = json.dumps({
  "buyer": {
    "name": "Teste NF TESTE","tradeName": "Comprador Nome Comercial","address": {"city": {"code": "1751488","name": "Marilia"
      },"state": "SP","district": "distrito","street": "Alameda Madri","postalCode": "1751488","number": "555","country": "BRA"},
    "federalTaxNumber": 99999999999999
  },
  "items": [{"code": "20968A","unitAmount": 87.9,"quantity": 33.9,"cfop": 5102, "ncm": "69072100","codeGTIN": "7894287914364",
      "codeTaxGTIN": "7894287914364","tax": {"totalTax": 6,"icms": {"csosn": "102","origin": "0"},"pis": { "amount": 0,"rate": 0,"baseTax": 208,          "cst": "08"
        },"cofins": {"amount": 0,"rate": 0,"baseTax": 208,"cst": "08"}},"cest": "","description": "TESTE DE PRODUTO - WITMOB"
    }]})
headers = {
  'Authorization': 't0StUhoH4JiSN72ehwrhq3nQ27gRDTSJGt2W98rDXilRTwhNoJAiGtM9WUcl9MscjjW',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.status_code)
# Out:
# 200

# %%
def execute_command(command):
    match command:
        case 'ls':
            print("teste1")
        case 'cd':
            print("teste2")

        case _:
            print("teste3")

execute_command('pwd')
# Out:
# teste3

# %%
def teste(command):
    match len(list(command)):
        case command if command >1:
            print('maior')

        case command if command ==1:
            print("é igual")

        case _:
            print("erro")
            
                

             
       


      
      
            

    
        
            
                

      
     
       
lista = ['oi']
a = teste(lista)
# Out:
# é igual

# %%
pip install ipykernel -U --force-reinstall
# Out:
# ...
#   Using cached ipykernel-6.16.1-py3-none-any.whl (138 kB)
# ...
#   Using cached nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# ...
#   Using cached jupyter_client-7.4.4-py3-none-any.whl (132 kB)
# ...
#   Using cached psutil-5.9.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
# ...
#   Using cached ipython-8.5.0-py3-none-any.whl (752 kB)
# ...
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# ...
#   Using cached traitlets-5.5.0-py3-none-any.whl (107 kB)
# ...
#   Using cached debugpy-1.6.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
# ...
#   Using cached matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# ...
#   Using cached pyzmq-24.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# ...
#   Using cached tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
# ...
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# ...

# %%
# Out:
# Running cells with 'Python 3.10.0 ('venv': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/debian/apiapp/venv/bin/python -m pip install ipykernel -U --force-reinstall'
